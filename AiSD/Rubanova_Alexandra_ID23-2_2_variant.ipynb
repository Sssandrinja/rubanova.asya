# %% [markdown]
# ### Контрольная работа № 1.
# ### Вариант 2.
# #### Студент: Рубанова Александра Денисовна; группа: ИД23-2

# %% [markdown]
# 1. Напишите программу, которая выполняет добавление, удаление и вывод на экран элементов списка при помощи классов.
#
# Решение задачи
#
# 1.	Создаем класс и с помощью конструктора инициализируем значения этого класса.
# 2.	Создаем в данном классе методы для добавления, удаления и вывода на экран соответствующих значений.
# 3.	Создаем объект данного класса.
# 4.	Используя созданный объект, вызываем соответствующий метод (в зависимости от выбора пользователя).
# 5.	Выводим результат на экран.
# 6.	Конец.
#
# В программе реализовать выбор с помощью меню:
#
# print("0. Выход")
#
# print("1. Добавить")
#
# print("2. Удалить")
#
# print("3. Вывести на экран")
#
# choice = int(input("Выберите одно из этих значений: "))

# %%
# Решение 1.

class NewList:
    def __init__(self):
        self.elements = []

    def add_element(self, element):
        self.elements.append(element)
        print(f"Элемент {element} добавлен в список.")

    def remove_element(self, element):
        if element in self.elements:
            self.elements.remove(element)
            print(f"Элемент {element} удален из списка.")
        else:
            print(f"Элемент {element} не найден в списке.")

    def display_elements(self):
        if self.elements:
            print("Элементы в списке: ")
            for element in self.elements:
                print(element)
        else:
            print("Список пуст.")


new_list = NewList()

while True:
    print("0. Выход")
    print("1. Добавить")
    print("2. Удалить")
    print("3. Вывести на экран")

    choice = int(input("Выберите одно из этих значений: "))
    if choice == 0:
        break
    elif choice == 1:
        element = input("Введите элемент для добавления: ")
        new_list.add_element(element)
    elif choice == 2:
        element = input("Введите элемент для удаления: ")
        new_list.remove_element(element)
    elif choice == 3:
        new_list.display_elements()
    else:
        print("Неверный выбор. Попробуйте снова")
# Out:
# 0. Выход
# 1. Добавить
# 2. Удалить
# 3. Вывести на экран
# Выберите одно из этих значений: 1
# Введите элемент для добавления: ШОКО
# Элемент ШОКО добавлен в список.
# 0. Выход
# 1. Добавить
# 2. Удалить
# 3. Вывести на экран
# Выберите одно из этих значений: 3
# Элементы в списке:
# ШОКО
# 0. Выход
# 1. Добавить
# 2. Удалить
# 3. Вывести на экран
# Выберите одно из этих значений: 1
# Введите элемент для добавления: ЛАДНИИЦА
# Элемент ЛАДНИИЦА добавлен в список.
# 0. Выход
# 1. Добавить
# 2. Удалить
# 3. Вывести на экран
# Выберите одно из этих значений: 3
# Элементы в списке:
# ШОКО
# ЛАДНИИЦА
# 0. Выход
# 1. Добавить
# 2. Удалить
# 3. Вывести на экран

# %% [markdown]
# 2. Используя класс People в качестве базового, создайте класс Сотрудник (Worker), имеющий свойства:
#
# • должность (post)
#
# • зарплата (salary)
#
# методы:
#
# • __init__ – конструктор;
#
# • __str__ – аналогично методу класса Teacher из примера.
#
# Используя класс Сотрудник в качестве базового создайте класс Преподаватель (Teacher), имеющий:
#
# • закрытый атрибут дисциплины (disciplines), в котором хранятся названия дисциплин, которые ведет преподаватель;
#
# • методы __init__ и __str__;
#
# • методы добавить_дисциплину (add_dis) и удалить_дисциплину (delete_dis), которые позволяют изменять список дисциплин.
#
# Создайте список, содержащий по 2 объекта каждого класса (People, Worker, Teacher). Для этого списка:
#
# • выведите информацию о каждом человеке с помощью метода info;
#
# • выведите фамилии тех, кто моложе 30 лет;
#
# • продемонстрируйте работу со свойствами должность и зарплата и методами добавить_дисциплину и удалить_дисциплину.

# %%
# Решение 2.

class People:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def info(self):
        return f"Name: {self.name}, Age: {self.age}"


class Worker(People):
    def __init__(self, name, age, post, salary):
        super().__init__(name, age)
        self.post = post
        self.salary = salary

    def __str__(self):
        return f"Name: {self.name}, Age: {self.age}, Post: {self.post}, Salary: {self.salary}"


class Teacher(Worker):
    def __init__(self, name, age, post, salary):
        super().__init__(name, age, post, salary)
        self.disciplines = []

    def add_dis(self, discipline):
        self.disciplines.append(discipline)

    def delete_dis(self, discipline):
        if discipline in self.disciplines:
            self.disciplines.remove(discipline)

    def __str__(self):
        return f"Name: {self.name}, Age: {self.age}, Post: {self.post}, Salary: {self.salary}, Disciplines: {', '.join(self.disciplines)}"


# примеры обьектов классов
people_list = [
    People("Sasha", 19),
    People("Kate", 20),
    Worker("Sergei", 20, "Genius", 50000),
    Worker("Kolya", 32, "Starosta", 10000),
    Teacher("Zenobius", 45, "Professor", 70000),
    Teacher("Zenobius 2.0", 45, "Ded", 55000)
]

# вывод информации о каждом человеке
for person in people_list:
    print(person.info())

# вывод фамилий тех, кто моложе 30 лет
print("\nМоложе 30:")
for person in people_list:
    if person.age < 30:
        print(person.name)

# еще примеры работы
teacher = Teacher("Soelma", 50, "Lector", 2500)
teacher.add_dis("Algebra")
teacher.add_dis("Discrete math")
print("\nУчитель до удаления дисциплины:")
print(teacher)
teacher.delete_dis("Discrete math")
print("\nУчитель после удаления дисциплины Discrete Math:")
print(teacher)
# Out:
# Name: Sasha, Age: 19
# Name: Kate, Age: 20
# Name: Sergei, Age: 20
# Name: Kolya, Age: 32
# Name: Zenobius, Age: 45
# Name: Zenobius 2.0, Age: 45
#
# Моложе 30:
# Sasha
# Kate
# Sergei
#
# Учитель до удаления дисциплины:
# Name: Soelma, Age: 50, Post: Lector, Salary: 2500, Disciplines: Algebra, Discrete math
#
# Учитель после удаления дисциплины Discrete Math:
# Name: Soelma, Age: 50, Post: Lector, Salary: 2500, Disciplines: Algebra

# %% [markdown]
# 3.Создайте класс Заказ(Order), у которого есть свойства кодтовара(code), цена(price), количество(count) и методы _init и str.
#
# Создайте 2 класса-потомка: Опт(Opt) и Розница(Retail). В этих классах создайте методы init, str.и сумма_заказа(summa), позволяющий узнать стоимость заказа. Для опта стоимость единицы товара составляет 95% от цены, а при покупке более 500 штук – 90% цены. В розницу стоимость единицы товара составляет 100% цены. Стоимость заказа равна произведению цены на количество.
#
# Продемонстрируйте работу с классами, создав необходимые объекты и обратившись к их свойствам и методам

# %%
# Решение 3.

class Order:
    def __init__(self, code, price, count):
        self.code = code
        self.price = price
        self.count = count

    def __str__(self):
        return f"Product Code: {self.code}, Price: {self.price}, Quantity: {self.count}"


class Opt(Order):
    def __init__(self, code, price, count):
        super().__init__(code, price, count)

    def __str__(self):
        return f"Product Code: {self.code}, Price: {self.price}, Quantity: {self.count}, Order Total: {self.summa()}"

    def summa(self):
        if self.count > 500:
            return self.price * self.count * 0.9
        else:
            return self.price * self.count * 0.95


class Retail(Order):
    def __init__(self, code, price, count):
        super().__init__(code, price, count)

    def __str__(self):
        return f"Product Code: {self.code}, Price: {self.price}, Amount: {self.count}, Order Total: {self.summa()}"

    def summa(self):
        return self.price * self.count

# пример использования класса
opt_order = Opt("123", 100, 600)
retail_order = Retail("456", 50, 10)

print("Opt Order:")
print(opt_order)
print("\nRetail Order:")
print(retail_order)
# Out:
# Opt Order:
# Product Code: 123, Price: 100, Quantity: 600, Order Total: 54000.0
#
# Retail Order:
# Product Code: 456, Price: 50, Amount: 10, Order Total: 500

# %% [markdown]
# 4.Написать функцию-генератор my_func_2(lst), которая принимает объект, поддерживающий итерации с произвольным уровнем вложенности, и возвращает все элементы по одному.

# %%
# Решение 4.

def my_func_2(lst):
    if isinstance(lst, (list, tuple, set)):
        for item in lst:
            yield from my_func_2(item)
    else:
        yield lst

lst = [1, [2, 3], [4, [5, 6]], 7]
for element in my_func_2(lst):
    print(element)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# 5.С помощью механизма map/filter/reduce (хотя бы одна из этих функций должна быть использована в решении) посчитать в тексте количество слов, состоящих не менее, чем из 3-х букв. Слова в тексте разделены пробелами. Написать реализацию в одну строку. Оформить решение в виде функции my_func_3(text), т.е. шаблон таков:
#
# строка с import, если необходимо def my_func_3(text): return # однострочная реализация задания

# %%
# Решение 5.

def my_func_3(text):
    return len(list(filter(lambda x: len(x) >= 3, text.split())))
